# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (12,2)

# %%
df_1 = pd.read_table("two_coil.XYZ", sep=" ")
df_2 = pd.read_table("two_coil_4_digits.XYZ", sep=" ")
df_3 = pd.read_table("two_coil_long.XYZ", sep=" ")
df_4 = pd.read_table("two_coil_long_unscent.XYZ", sep=" ")

# %%
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 1])
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 1])

# %%
plt.plot(df_4.iloc[:, 0], df_4.iloc[:, 1])
plt.plot(df_3.iloc[:, 0], df_3.iloc[:, 1])

# %%
plt.plot(df_3.iloc[:1000, 0], df_3.iloc[:1000, 7])
plt.plot(df_4.iloc[:1000, 0], df_4.iloc[:1000, 7])

# %%
plt.plot(df_4.iloc[:1000, 0], [min(i, 5) for i in df_4.iloc[:1000, 8]])
plt.plot(df_3.iloc[:1000, 0], [min(i, 5) for i in df_3.iloc[:1000, 8]])

# %%
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 7])
plt.show()
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 1])
plt.show()
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 2])
plt.show()
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 3])
plt.show()
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 4])
plt.show()
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 5])
plt.show()
plt.plot(df_4.iloc[:300, 0], df_4.iloc[:300, 6])
plt.show()

# %%
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 7])
plt.show()
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 1])
plt.show()
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 2])
plt.show()
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 3])
plt.show()
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 4])
plt.show()
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 5])
plt.show()
plt.plot(df_3.iloc[:300, 0], df_3.iloc[:300, 6])
plt.show()
